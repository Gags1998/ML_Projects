# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv(r"C:\Users\gagan\Downloads\archive (4)\winequality-red.csv")

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data['citric acid'].value_counts()
# Out:
# citric acid
# 0.00    132
# 0.49     68
# 0.24     51
# 0.02     50
# 0.26     38
#        ...
# 0.79      1
# 0.71      1
# 0.72      1
# 0.75      1
# 0.78      1
# Name: count, Length: 80, dtype: int64

# %%
data.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
sns.scatterplot(data=data, x=data['density'],y=data['sulphates'])
# Out:
# <Axes: xlabel='density', ylabel='sulphates'>

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
y = data['fixed acidity'] # all the columns except sales column , Basically all the features thagond edhare [features means columns]
x = data[['density','citric acid','pH']]

# %%
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25)
print(x_train.shape, y_train.shape)
# Out:
# (1199, 3) (1199,)

# %%
model= LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [396.36229516   2.81709655  -4.41025482]
# -372.9183883190819

# %%
y_pred = model.predict(x_test)
from sklearn.metrics import r2_score
score = r2_score(y_test, y_pred)
print(score)
# Out:
# 0.727120597444779

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, x, y, cv = 5)
print(scores.mean())
# Out:
# 0.5988748894748234
